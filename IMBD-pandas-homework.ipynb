# %% [markdown]
# # Pandas Homework with IMDB Data
#
# Work with the [IMBD data](https://raw.githubusercontent.com/ga-students/ds-dc-23/master/2_dataset/imdb_1000.csv?token=ANUte-is8-dJ4XeomBvRCR8TulLjD9pdks5aAPGBwA%3D%3D) inside our repository.

# %% [markdown]
# ## BASIC LEVEL

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in 'imdb_1000.csv' and store it in a DataFrame named movies
movies = pd.read_table('C:/Users/cmagann/Desktop/GA_DS/Fork/ds-dc-23/2_dataset/imdb_1000.csv', sep=',')

# %%
# check the number of rows and columns
movies.shape
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# check the data type of each column
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# calculate the average movie duration
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
# sort the DataFrame by duration to find the shortest and longest movies
movies.sort_values(by = 'duration', ascending=False)
# Out:
#      star_rating                                          title  \
# 476          7.8                                         Hamlet
# 157          8.2                             Gone with the Wind
# 78           8.4                    Once Upon a Time in America
# 142          8.3              Lagaan: Once Upon a Time in India
# 445          7.9                           The Ten Commandments
# 85           8.4                             Lawrence of Arabia
# 204          8.1                                        Ben-Hur
# 17           8.7                                  Seven Samurai
# 767          7.6                It's a Mad, Mad, Mad, Mad World
# 630          7.7                                      Malcolm X
# 7            8.9  The Lord of the Rings: The Return of the King
# 2            9.1                         The Godfather: Part II
# 335          8.0                                 Doctor Zhivago
# 385          8.0                                      Spartacus
# ...

# %%
# create a histogram of duration, choosing an "appropriate" number of bins
# %matplotlib inline
#movies.duration.plot(kind = 'hist', bins=60)
movies.duration.plot(kind = 'hist', bins=25)
plt.xlabel('Duration')
plt.legend()

# %%
# use a box plot to display that same data
# %matplotlib inline
movies.duration.plot(kind='box')

# %% [markdown]
# ## INTERMEDIATE LEVEL

# %%
# count how many movies have each of the content ratings
movies.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
# use a visualization to display that same data, including a title and x and y labels

# %%
movies.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
# convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP
movies['content_rating'] = movies['content_rating'].replace(['NOT RATED', 'APPROVED', 'PASSED', 'GP'], 'UNRATED')
movies.content_rating.value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    160
# PG         123
# G           32
# NC-17        7
# X            4
# TV-MA        1
# Name: content_rating, dtype: int64

# %%
# convert the following content ratings to "NC-17": X, TV-MA
movies['content_rating'] = movies['content_rating'].replace(['X', 'TV-MA'], 'NC-17')
movies.content_rating.value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    160
# PG         123
# G           32
# NC-17       12
# Name: content_rating, dtype: int64

# %%
# count the number of missing values in each column
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
# if there are missing values: examine them, then fill them in with "reasonable" values
movies[movies.content_rating.isnull()]
movies['content_rating'] = movies['content_rating'].fillna(value = 'PG-13')

# %%
# calculate the average star rating for movies 2 hours or longer,
# and compare that with the average star rating for movies shorter than 2 hours
movies[movies.duration > 120].star_rating.mean()
# Out:
# 7.953669724770622

# %%
movies[movies.duration < 120].star_rating.mean()
# Out:
# 7.838666666666657

# %%
# use a visualization to detect whether there is a relationship between duration and star rating
# my note: create a scatterplot
# movies.plot(kind='scatter', y='star_rating', x='duration')
# movies.plot(kind='scatter', x='star_rating', y='duration')
movies.plot(kind = 'scatter', x = 'star_rating', y = 'duration', alpha = 0.5)
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
# calculate the average duration for each genre
# movies['genre'].unique() & movies.duration.mean()
# drinks.groupby('continent').beer.mean()
movies.groupby('genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
# calculate the average duration for each genre

# %% [markdown]
# ## ADVANCED LEVEL

# %%
# visualize the relationship between content rating and duration
# movies.plot(kind='scatter', y = 'duration', x = 'content_rating') < oops cant map this :)
# movies.head()
#movies.duration.hist(by = movies.content_rating)
# %matplotlib inline
movies.duration.plot(kind='hist', y = 'duration', x = 'star_rating', bins=25)
plt.xlabel('Duration')
plt.legend()

# %%
# determine the top rated movie (by star rating) for each genre
  # movies.groupby('genre').title.first()
  # movies.sort('star_rating', ascending=False)
# movies.groupby('star_rating').sort_values(ascending=False) < still working on this one :)
movies.sort_values(by = 'star_rating', ascending=False)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# ...

# %%
# check if there are multiple movies with the same title, and if so, determine if they are actually duplicates
movies[movies.title.duplicated()].title
# still working this one
# Out:
# 482    The Girl with the Dragon Tattoo
# 905                            Dracula
# 924                     Les Miserables
# 936                          True Grit
# Name: title, dtype: object

# %%
# calculate the average star rating for each genre, but only include genres with at least 10 movies

# option 1: manually create a list of relevant genres, then filter using that list

# option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# option 3: calculate the average star rating for all genres, then filter using a boolean Series

# option 4: aggregate by count and mean, then filter using the count

# %% [markdown]
# ## BONUS

# %%
# Figure out something "interesting" using the actors data!
